# %% [markdown]
# # Data Processing

# %% [markdown]
# ## 1. Load Data

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#import dataset as data frame
lyrics = pd.read_csv('./lyrics.csv')

# %% [markdown]
# ## 2. Preview Data

# %%
#data frame header
lyrics.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  If you search\nFor tenderness\nIt isn't hard t...
# 3  Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...
# 4  Party the people, the people the party it's po...

# %%
#number of unique artists
lyrics.artist.unique().shape[0]
# Out:
# 18231

# %%
#data for childish gambino
lyrics_childish = lyrics.loc[lyrics['artist'] == 'childish-gambino']
lyrics_childish.head()
# Out:
#          index                                    song  year  \
# 346741  346741  because-the-internet-screenplay-part-3  2013
# 346742  346742                          the-worst-guys  2013
# 346743  346743                            regular-show  2013
# 346744  346744                             think-of-me  2013
# 346745  346745                             i-the-crawl  2013
#
#                   artist    genre  \
# 346741  childish-gambino  Hip-Hop
# 346742  childish-gambino  Hip-Hop
# 346743  childish-gambino  Hip-Hop
# 346744  childish-gambino  Hip-Hop
# 346745  childish-gambino  Hip-Hop
#
#                                                    lyrics
# 346741  *******[PLAY SECRET TRACK 9 1/2 [CODED]Â NOW]...
# 346742  All she needed was some\nAt a Clippers' game o...
# 346743  [Big Trouble (Tyler the Creator)]\nY'all bette...
# 346744                                                NaN
# 346745  Where we were, kinda thing, betcha crawl, all ...

# %% [markdown]
# ## 3. Clean Data

# %%
#notice null values
pd.isnull(lyrics_childish)
# Out:
#         index   song   year  artist  genre  lyrics
# 346741  False  False  False   False  False   False
# 346742  False  False  False   False  False   False
# 346743  False  False  False   False  False   False
# 346744  False  False  False   False  False    True
# 346745  False  False  False   False  False   False
# 346746  False  False  False   False  False   False
# 346747  False  False  False   False  False    True
# 346748  False  False  False   False  False   False
# 346749  False  False  False   False  False   False
# 346750  False  False  False   False  False   False
# 346751  False  False  False   False  False   False
# 346752  False  False  False   False  False   False
# 346753  False  False  False   False  False   False
# 346754  False  False  False   False  False   False
# 346755  False  False  False   False  False   False
# 346756  False  False  False   False  False   False
# 346757  False  False  False   False  False   False
# 346758  False  False  False   False  False   False
# 346759  False  False  False   False  False   False
# 346760  False  False  False   False  False   False
# 346761  False  False  False   False  False   False
# 346762  False  False  False   False  False   False
# 346763  False  False  False   False  False   False
# 346764  False  False  False   False  False   False
# 346765  False  False  False   False  False   False
# 346766  False  False  False   False  False   False
# 346767  False  False  False   False  False   False
# 346768  False  False  False   False  False   False
# 346769  False  False  False   False  False   False
# 346770  False  False  False   False  False   False
# ...       ...    ...    ...     ...    ...     ...
# 346856  False  False  False   False  False    True
# 346857  False  False  False   False  False   False
# 346858  False  False  False   False  False    True
# 346859  False  False  False   False  False    True
# 346860  False  False  False   False  False   False
# 346861  False  False  False   False  False   False
# 346862  False  False  False   False  False   False
# 346863  False  False  False   False  False   False
# 346864  False  False  False   False  False    True
# 346865  False  False  False   False  False   False
# 346866  False  False  False   False  False   False
# 346867  False  False  False   False  False   False
# 346868  False  False  False   False  False   False
# 346869  False  False  False   False  False   False
# 346870  False  False  False   False  False   False
# 346871  False  False  False   False  False   False
# 346872  False  False  False   False  False   False
# 346873  False  False  False   False  False   False
# 346874  False  False  False   False  False   False
# 346875  False  False  False   False  False   False
# 346876  False  False  False   False  False   False
# 346877  False  False  False   False  False    True
# 346878  False  False  False   False  False   False
# 346879  False  False  False   False  False   False
# 346880  False  False  False   False  False   False
# 346881  False  False  False   False  False   False
# 346882  False  False  False   False  False   False
# 346883  False  False  False   False  False   False
# 346884  False  False  False   False  False   False
# 346885  False  False  False   False  False   False
#
# [145 rows x 6 columns]

# %%
#remove rows with null lyrics
lyrics_childish = lyrics_childish[pd.notnull(lyrics_childish['lyrics'])]
lyrics_childish.head()
# Out:
#          index                                           song  year  \
# 346741  346741         because-the-internet-screenplay-part-3  2013
# 346742  346742                                 the-worst-guys  2013
# 346743  346743                                   regular-show  2013
# 346745  346745                                    i-the-crawl  2013
# 346746  346746  iii-life-the-biggest-troll-andrew-auernheimer  2013
#
#                   artist    genre  \
# 346741  childish-gambino  Hip-Hop
# 346742  childish-gambino  Hip-Hop
# 346743  childish-gambino  Hip-Hop
# 346745  childish-gambino  Hip-Hop
# 346746  childish-gambino  Hip-Hop
#
#                                                    lyrics
# 346741  *******[PLAY SECRET TRACK 9 1/2 [CODED]Â NOW]...
# 346742  All she needed was some\nAt a Clippers' game o...
# 346743  [Big Trouble (Tyler the Creator)]\nY'all bette...
# 346745  Where we were, kinda thing, betcha crawl, all ...
# 346746  Man made the web, you don't need a name\nMan m...

# %% [markdown]
# ## 4. Preview Sample

# %%
#sample of first song lyrics
demo1 = lyrics_childish.lyrics.iloc[0]
demo1
# Out:
# '*******[PLAY SECRET TRACK 9 1/2 [CODED]Â\x9d NOW]*******\n(do not read on while "Secret track" plays. Wait until it is finished, then continue reading)\nCUT TO:\n****[PLAY "PLAYING AROUND BEFORE THE PARTY STARTS" NOW]****\nINT. MANSION - NIGHT\n[VISUAL]\nThe Boy sits at his piano; playing randomly, trying to make sense of everything/anything. Steve and Swank talk to Emily and MISLA in the kitchen. They\'re arguing about driving, or cooking with coconut oil instead of olive oil, or something else they themselves will not care about or remember in a month, year, ten years, 100 years, the age of the universe\nThe house is starting to look pretty bad. The cleaners that used to come stopped receiving their payment and stopped coming. Plastic cups are starting to spread like a blue rash across the living room and coffee tables. Every surface has a sticky spot. You used to be able to slide into the kitchen from the living room with a two second run and quick stop. Now, dried alcohol stops you before you even get to the kitchen door. The Boy really loved sliding into the kitchen when he was a kid. It was the closest you could get to having powers\n*******[PLAY SONG "THE PARTY" AT THIS POINT]*******\n[VISUAL]\nMinutes go by. People start to crowd around The Boy as he continues on piano. So many people he can\'t think\nFam daps up a kid as he walks in. They then walk over to a closet where Fam opens up a pantry of weed. It\'s not nostalgic rap video stocked with weed, but there\'s a lot of weed in there. Fam tosses an ounce of weed at the kid. The kid and his friend smell it and nod. They look to Fam to share a smile of like "good shit, right?", but Fam isn\'t there for em. Fam gives em the "where\'s my money you privileged ass-hole" look. They pull out some hundreds\nMisla is sitting knees to chest with a french dude in the center of the pool table. They\'re eating s\'mores\nEmily and Steve are jumping over the fire pit like idiots\nThere are people saying things, giving opinions, feeling interesting. Everyone has a purpose tonight. It\'s a great time\nBut then:\n...this is a waste\n THE BOY: Get\n...of time\n THE BOY (CONT\'D): Out. Everyone\nNo one can hear him. It\'s a party\n THE BOY (CONT\'D): Everyone needs to get out. NOW!\nPeople start to notice. The Boy gets up from the piano and grabs a pool stick. He quickly walks over to the ipod dock playing music and winds up like it\'s a bat\nSMASH\nEveryone stares\n FUCKBOY 2: That\'s my phone, nigga!\nThe Boy looks up. There\'s a deep inhale, then he starts smashing everything. Glass sprays everywhere, alcohol splashes, people start running out\nSOME DUDE 2: Worldstar!\nThe Boy continues hitting things. He\'s about to come down on somoeone\'s phone that\'s lying on the coffee table. He holds the pool cue above his head and lets it down fast\nBut right before, someone grabs the cell phone, laying their hand on top of it, daring The Boy to hit the hand. The Boy barely stops in time\nThe hand has a cast on it. The Boy looks up to see a girl (NAOMI) staring at him. She looks mad. The Boy is mad. But not at her. He\'s trying to look mad at her, but he really looks like "sorry"\nEyes locked\nShe slowly takes her phone, making complete eye contact the entire time, then walks out. Everyone stares at this strange interaction\nAs soon as she leaves, The Boy goes back to smashing things\n THE BOY: Get out! Get away!\nSome people start running out trying not to get hit. Other people just laugh cause they\'re high or because they think it\'s pathetic. They all leave eventually\nThe Boy stands there for a moment. He turns to the bar next to the pool table. There\'s half a blunt and a bottle of Sriracha sitting there. The Boy takes the bottle and starts squirting it on the pool table\nWhen he\'s done, he\'s written: "ROSCOE\'S WETSUIT"\n FAM: Nice\nThe Boy turns. Fam\'s just sitting there. No one even noticed him. Fam gives him a SMH. The Boy leaves\nCUT TO:\n*******[PLAY SONG "NO EXIT" AT THIS POIN ...

# %% [markdown]
# ## 5.a. Save Data (Childish Gambino)

# %%
#save string as txt file
f = open("./demo1.txt","w+")
f.write(demo1)
f.close()

# %%
#iterate and save through all song lyrics
n = lyrics_childish.shape[0]
for i in range(n):
    f = open("./artists/childish_gambino/" + lyrics_childish.song.iloc[i] + ".txt","w+")
    f.write(lyrics_childish.lyrics.iloc[i])
    f.close()

# %% [markdown]
# ## 5.b. Save Data (Drake)

# %%
#data for drake
lyrics_drake = lyrics.loc[lyrics['artist'] == 'drake']
#remove rows with null lyrics
lyrics_drake = lyrics_drake[pd.notnull(lyrics_drake['lyrics'])]

#iterate and save through all song lyrics
n = lyrics_drake.shape[0]
for i in range(n):
    f = open("./artists/drake/" + lyrics_drake.song.iloc[i] + ".txt","w+")
    f.write(lyrics_drake.lyrics.iloc[i])
    f.close()

# %% [markdown]
# ## 5.c. Save Data (Frank Ocean)

# %%
#data for frank ocean
lyrics_frank = lyrics.loc[lyrics['artist'] == 'frank-ocean']
#remove rows with null lyrics
lyrics_frank = lyrics_frank[pd.notnull(lyrics_frank['lyrics'])]

#iterate and save through all song lyrics
n = lyrics_frank.shape[0]
for i in range(n):
    f = open("./artists/frank_ocean/" + lyrics_frank.song.iloc[i] + ".txt","w+")
    f.write(lyrics_frank.lyrics.iloc[i])
    f.close()
